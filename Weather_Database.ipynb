# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
from citipy import citipy
# Import timeit.
import timeit

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
import requests
requests.__version__


# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=56ee96cf1afbe149590ff90c54a0a712

# %%
# Out:
#   File "<ipython-input-17-20fa55b2a761>", line 3
#     print(city_weather)
#                        ^
# SyntaxError: unexpected EOF while parsing

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | muros
# Processing Record 2 of Set 1 | hasaki
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | hirara
# Processing Record 5 of Set 1 | olenegorsk
# Processing Record 6 of Set 1 | yulara
# Processing Record 7 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 1 | banda aceh
# Processing Record 9 of Set 1 | samarai
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | teshie
# Processing Record 13 of Set 1 | boende
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | riyadh
# Processing Record 17 of Set 1 | hakkari
# Processing Record 18 of Set 1 | havre-saint-pierre
# Processing Record 19 of Set 1 | palmer
# Processing Record 20 of Set 1 | codrington
# Processing Record 21 of Set 1 | bereda
# Processing Record 22 of Set 1 | nikolskoye
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | saskylakh
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | arica
# Processing Record 27 of Set 1 | clovis
# Processing Record 28 of Set 1 | longyearbyen
# Processing Record 29 of Set 1 | aklavik
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | vestmannaeyjar
# Processing Record 35 of Set 1 | abapo
# Processing Record 36 of Set 1 | noumea
# Processing Record 37 of Set 1 | teguise
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | severo-kurilsk
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | lalpur
# Processing Record 42 of Set 1 | mandalgovi
# Processing Record 43 of Set 1 | inuvik
# Processing Record 44 of Set 1 | nemuro
# Processing Record 45 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 1 | saint-joseph
# Processing Record 47 of Set 1 | bengkulu
# Processing Record 48 of Set 1 | vardo
# Processing Record 49 of Set 1 | bonavista
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | mwinilunga
# Processing Record 2 of Set 2 | florida
# Processing Record 3 of Set 2 | dauphin
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | nhulunbuy
# Processing Record 6 of Set 2 | san patricio
# Processing Record 7 of Set 2 | novobiryusinskiy
# Processing Record 8 of Set 2 | shasta lake
# Processing Record 9 of Set 2 | thompson
# Processing Record 10 of Set 2 | juruti
# Processing Record 11 of Set 2 | gobabis
# Processing Record 12 of Set 2 | sumbawanga
# Processing Record 13 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 2 | port-cartier
# Processing Record 16 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 2 | isla vista
# Processing Record 18 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 2 | turukhansk
# Processing Record 20 of Set 2 | arraial do cabo
# Processing Record 21 of Set 2 | mataura
# Processing Record 22 of Set 2 | husavik
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | alofi
# Processing Record 25 of Set 2 | porto novo
# Processing Record 26 of Set 2 | liverpool
# Processing Record 27 of Set 2 | gbarnga
# Processing Record 28 of Set 2 | san carlos
# Processing Record 29 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 2 | zhuhai
# Processing Record 31 of Set 2 | bambous virieux
# Processing Record 32 of Set 2 | ixtapa
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | saldanha
# Processing Record 35 of Set 2 | kargasok
# Processing Record 36 of Set 2 | cabo san lucas
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | epe
# Processing Record 39 of Set 2 | bethel
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 44 of Set 2 | tura
# Processing Record 45 of Set 2 | kyra
# Processing Record 46 of Set 2 | simbahan
# Processing Record 47 of Set 2 | kalmunai
# Processing Record 48 of Set 2 | kaitangata
# Processing Record 49 of Set 2 | yumen
# Processing Record 50 of Set 2 | ust-ordynskiy
# Processing Record 1 of Set 3 | zachagansk
# City not found. Skipping...
# Processing Record 2 of Set 3 | clyde river
# Processing Record 3 of Set 3 | esmeraldas
# Processing Record 4 of Set 3 | yerbogachen
# Processing Record 5 of Set 3 | tangier
# Processing Record 6 of Set 3 | tuktoyaktuk
# Processing Record 7 of Set 3 | karangasem
# Processing Record 8 of Set 3 | saint-leu
# Processing Record 9 of Set 3 | batagay
# Processing Record 10 of Set 3 | tuatapere
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | buchanan
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | ahipara
# Processing Record 15 of Set 3 | hermanus
# Processing Record 16 of Set 3 | puerto ayora
# Processing Record 17 of Set 3 | isla del bosque
# Processing Record 18 of Set 3 | yellowknife
# Processing Record 19 of Set 3 | victoria
# Processing Record 20 of Set 3 | dikson
# Processing Record 21 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 3 | torbay
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | ilulissat
# Processing Record 25 of Set 3 | komsomolskiy
# Processing Record 26 of Set 3 | pevek
# Processing Record 27 of Set 3 | ambilobe
# Processing Record 28 of Set 3 | narsaq
# Processing Record 29 of Set 3 | rongcheng
# Processing Record 30 of Set 3 | dzaoudzi
# Processing Record 31 of Set 3 | zhigansk
# Processing Record 32 of Set 3 | mangrol
# Processing Record 33 of Set 3 | kasamwa
# Processing Record 34 of Set 3 | chokurdakh
# Processing Record 35 of Set 3 | kilsyth
# Processing Record 36 of Set 3 | sitka
# Processing Record 37 of Set 3 | paamiut
# Processing Record 38 of Set 3 | orillia
# Processing Record 39 of Set 3 | mehamn
# Processing Record 40 of Set 3 | westport
# Processing Record 41 of Set 3 | atuona
# Processing Record 42 of Set 3 | geraldton
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | bata
# Processing Record 45 of Set 3 | birin
# Processing Record 46 of Set 3 | touros
# Processing Record 47 of Set 3 | mount gambier
# Processing Record 48 of Set 3 | punta arenas
# Processing Record 49 of Set 3 | alugan
# Processing Record 50 of Set 3 | lompoc
# Processing Record 1 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 2 of Set 4 | saint george
# Processing Record 3 of Set 4 | port hardy
# Processing Record 4 of Set 4 | smirnykh
# Processing Record 5 of Set 4 | cherskiy
# Processing Record 6 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 4 | lukulu
# Processing Record 8 of Set 4 | yarada
# Processing Record 9 of Set 4 | virginia beach
# Processing Record 10 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 4 | avera
# Processing Record 12 of Set 4 | los llanos de aridane
# Processing Record 13 of Set 4 | esperance
# Processing Record 14 of Set 4 | provideniya
# Processing Record 15 of Set 4 | novyy urengoy
# Processing Record 16 of Set 4 | homer
# Processing Record 17 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 4 | caravelas
# Processing Record 19 of Set 4 | mayo
# Processing Record 20 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 4 | yar-sale
# Processing Record 22 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 4 | chicama
# Processing Record 24 of Set 4 | conchagua
# Processing Record 25 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 4 | tromso
# Processing Record 27 of Set 4 | saint-augustin
# Processing Record 28 of Set 4 | katete
# Processing Record 29 of Set 4 | dhidhdhoo
# Processing Record 30 of Set 4 | hobart
# Processing Record 31 of Set 4 | klaksvik
# Processing Record 32 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 34 of Set 4 | angra
# City not found. Skipping...
# Processing Record 35 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 36 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 37 of Set 4 | kodinsk
# Processing Record 38 of Set 4 | solnechnyy
# Processing Record 39 of Set 4 | cochrane
# Processing Record 40 of Set 4 | varkaus
# Processing Record 41 of Set 4 | qaqortoq
# Processing Record 42 of Set 4 | emerald
# Processing Record 43 of Set 4 | kodiak
# Processing Record 44 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 4 | bud
# Processing Record 46 of Set 4 | weinan
# Processing Record 47 of Set 4 | hambantota
# Processing Record 48 of Set 4 | pemangkat
# Processing Record 49 of Set 4 | bhadrachalam
# Processing Record 50 of Set 4 | cururupu
# Processing Record 1 of Set 5 | beloha
# Processing Record 2 of Set 5 | zapolyarnyy
# Processing Record 3 of Set 5 | agadez
# Processing Record 4 of Set 5 | along
# Processing Record 5 of Set 5 | aykhal
# Processing Record 6 of Set 5 | heihe
# Processing Record 7 of Set 5 | wencheng
# Processing Record 8 of Set 5 | gushi
# Processing Record 9 of Set 5 | kenora
# Processing Record 10 of Set 5 | acari
# Processing Record 11 of Set 5 | makakilo city
# Processing Record 12 of Set 5 | khatanga
# Processing Record 13 of Set 5 | kruisfontein
# Processing Record 14 of Set 5 | waddan
# Processing Record 15 of Set 5 | buinsk
# Processing Record 16 of Set 5 | toulepleu
# City not found. Skipping...
# Processing Record 17 of Set 5 | qaanaaq
# Processing Record 18 of Set 5 | toro
# Processing Record 19 of Set 5 | aswan
# Processing Record 20 of Set 5 | angoche
# Processing Record 21 of Set 5 | canutama
# Processing Record 22 of Set 5 | talcahuano
# Processing Record 23 of Set 5 | rabo de peixe
# Processing Record 24 of Set 5 | lavrentiya
# Processing Record 25 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 5 | okitipupa
# Processing Record 27 of Set 5 | noyabrsk
# Processing Record 28 of Set 5 | necochea
# Processing Record 29 of Set 5 | sobolevo
# Processing Record 30 of Set 5 | mahebourg
# Processing Record 31 of Set 5 | faanui
# Processing Record 32 of Set 5 | andijon
# Processing Record 33 of Set 5 | zhongshu
# Processing Record 34 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 35 of Set 5 | rancho palos verdes
# Processing Record 36 of Set 5 | henties bay
# Processing Record 37 of Set 5 | karakose
# City not found. Skipping...
# Processing Record 38 of Set 5 | saint-francois
# Processing Record 39 of Set 5 | inongo
# Processing Record 40 of Set 5 | san cristobal
# Processing Record 41 of Set 5 | sao gabriel da cachoeira
# Processing Record 42 of Set 5 | turayf
# Processing Record 43 of Set 5 | ewa beach
# Processing Record 44 of Set 5 | grindavik
# Processing Record 45 of Set 5 | piracicaba
# Processing Record 46 of Set 5 | chuy
# Processing Record 47 of Set 5 | guerrero negro
# Processing Record 48 of Set 5 | port-gentil
# Processing Record 49 of Set 5 | tasiilaq
# Processing Record 50 of Set 5 | medak
# Processing Record 1 of Set 6 | kahului
# Processing Record 2 of Set 6 | xichang
# Processing Record 3 of Set 6 | tashtagol
# Processing Record 4 of Set 6 | leningradskiy
# Processing Record 5 of Set 6 | adrar
# Processing Record 6 of Set 6 | dalby
# Processing Record 7 of Set 6 | hithadhoo
# Processing Record 8 of Set 6 | huarmey
# Processing Record 9 of Set 6 | coihaique
# Processing Record 10 of Set 6 | davila
# Processing Record 11 of Set 6 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 12 of Set 6 | evensk
# Processing Record 13 of Set 6 | kavieng
# Processing Record 14 of Set 6 | wanxian
# Processing Record 15 of Set 6 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 16 of Set 6 | san quintin
# Processing Record 17 of Set 6 | bilibino
# Processing Record 18 of Set 6 | padang
# Processing Record 19 of Set 6 | mount isa
# Processing Record 20 of Set 6 | dunedin
# Processing Record 21 of Set 6 | taganak
# Processing Record 22 of Set 6 | jamestown
# Processing Record 23 of Set 6 | meulaboh
# Processing Record 24 of Set 6 | roebourne
# Processing Record 25 of Set 6 | krasnokholmskiy
# Processing Record 26 of Set 6 | nadym
# Processing Record 27 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 28 of Set 6 | hovd
# Processing Record 29 of Set 6 | torit
# Processing Record 30 of Set 6 | kushima
# Processing Record 31 of Set 6 | krasnovishersk
# Processing Record 32 of Set 6 | ribeira grande
# Processing Record 33 of Set 6 | manzil jamil
# City not found. Skipping...
# Processing Record 34 of Set 6 | marondera
# Processing Record 35 of Set 6 | burnie
# Processing Record 36 of Set 6 | aksu
# Processing Record 37 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 38 of Set 6 | ponta do sol
# Processing Record 39 of Set 6 | maningrida
# Processing Record 40 of Set 6 | tautira
# Processing Record 41 of Set 6 | berdigestyakh
# Processing Record 42 of Set 6 | umm lajj
# Processing Record 43 of Set 6 | iqaluit
# Processing Record 44 of Set 6 | ranau
# Processing Record 45 of Set 6 | conceicao do araguaia
# Processing Record 46 of Set 6 | talnakh
# Processing Record 47 of Set 6 | yilan
# Processing Record 48 of Set 6 | antalaha
# Processing Record 49 of Set 6 | waipawa
# Processing Record 50 of Set 6 | ust-kut
# Processing Record 1 of Set 7 | ecublens
# Processing Record 2 of Set 7 | bredasdorp
# Processing Record 3 of Set 7 | broome
# Processing Record 4 of Set 7 | camacha
# Processing Record 5 of Set 7 | monastyrshchina
# Processing Record 6 of Set 7 | os
# City not found. Skipping...
# Processing Record 7 of Set 7 | udachnyy
# Processing Record 8 of Set 7 | anadyr
# Processing Record 9 of Set 7 | iroquois falls
# Processing Record 10 of Set 7 | flinders
# Processing Record 11 of Set 7 | cizre
# Processing Record 12 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 7 | new norfolk
# Processing Record 14 of Set 7 | luderitz
# Processing Record 15 of Set 7 | lazo
# Processing Record 16 of Set 7 | axim
# Processing Record 17 of Set 7 | cacoal
# Processing Record 18 of Set 7 | kisangani
# Processing Record 19 of Set 7 | sann
# Processing Record 20 of Set 7 | kebonarum
# City not found. Skipping...
# Processing Record 21 of Set 7 | valleyview
# Processing Record 22 of Set 7 | frontera
# Processing Record 23 of Set 7 | manzhouli
# Processing Record 24 of Set 7 | lagoa vermelha
# Processing Record 25 of Set 7 | fort nelson
# Processing Record 26 of Set 7 | barabai
# Processing Record 27 of Set 7 | nanortalik
# Processing Record 28 of Set 7 | naze
# Processing Record 29 of Set 7 | brae
# Processing Record 30 of Set 7 | honiara
# Processing Record 31 of Set 7 | aquiraz
# Processing Record 32 of Set 7 | kieta
# Processing Record 33 of Set 7 | bolshaya irba
# City not found. Skipping...
# Processing Record 34 of Set 7 | suluq
# Processing Record 35 of Set 7 | tanout
# Processing Record 36 of Set 7 | chulucanas
# Processing Record 37 of Set 7 | raudeberg
# Processing Record 38 of Set 7 | korla
# Processing Record 39 of Set 7 | carutapera
# Processing Record 40 of Set 7 | kosino
# Processing Record 41 of Set 7 | zhuanghe
# Processing Record 42 of Set 7 | cabedelo
# Processing Record 43 of Set 7 | cockburn town
# Processing Record 44 of Set 7 | cravo norte
# Processing Record 45 of Set 7 | kalianget
# Processing Record 46 of Set 7 | mao
# Processing Record 47 of Set 7 | nishihara
# Processing Record 48 of Set 7 | warrnambool
# Processing Record 49 of Set 7 | saint-avold
# Processing Record 50 of Set 7 | tecoanapa
# Processing Record 1 of Set 8 | zyryanka
# Processing Record 2 of Set 8 | bosaso
# Processing Record 3 of Set 8 | kjollefjord
# Processing Record 4 of Set 8 | nizhniy chir
# Processing Record 5 of Set 8 | azul
# Processing Record 6 of Set 8 | carauari
# Processing Record 7 of Set 8 | grand gaube
# Processing Record 8 of Set 8 | marawi
# Processing Record 9 of Set 8 | placerville
# Processing Record 10 of Set 8 | te anau
# Processing Record 11 of Set 8 | matsanga
# City not found. Skipping...
# Processing Record 12 of Set 8 | cidreira
# Processing Record 13 of Set 8 | ust-tsilma
# Processing Record 14 of Set 8 | ravar
# Processing Record 15 of Set 8 | baherden
# Processing Record 16 of Set 8 | sao joao da barra
# Processing Record 17 of Set 8 | kenai
# Processing Record 18 of Set 8 | asau
# Processing Record 19 of Set 8 | copiapo
# Processing Record 20 of Set 8 | ust-maya
# Processing Record 21 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 22 of Set 8 | tabatinga
# Processing Record 23 of Set 8 | baishishan
# Processing Record 24 of Set 8 | tygda
# Processing Record 25 of Set 8 | port blair
# Processing Record 26 of Set 8 | pangkalanbuun
# Processing Record 27 of Set 8 | saint john
# Processing Record 28 of Set 8 | maceio
# Processing Record 29 of Set 8 | gramoteino
# Processing Record 30 of Set 8 | chimbote
# Processing Record 31 of Set 8 | salalah
# Processing Record 32 of Set 8 | bathsheba
# Processing Record 33 of Set 8 | fengzhen
# Processing Record 34 of Set 8 | santa barbara
# Processing Record 35 of Set 8 | zhezkazgan
# Processing Record 36 of Set 8 | lorengau
# Processing Record 37 of Set 8 | laguna
# Processing Record 38 of Set 8 | barpali
# Processing Record 39 of Set 8 | victor harbor
# Processing Record 40 of Set 8 | katsuura
# Processing Record 41 of Set 8 | neryungri
# Processing Record 42 of Set 8 | griffith
# Processing Record 43 of Set 8 | bowen
# Processing Record 44 of Set 8 | biak
# Processing Record 45 of Set 8 | stournaraiika
# City not found. Skipping...
# Processing Record 46 of Set 8 | rio grande
# Processing Record 47 of Set 8 | souillac
# Processing Record 48 of Set 8 | bhor
# Processing Record 49 of Set 8 | tilichiki
# Processing Record 50 of Set 8 | baruun-urt
# Processing Record 1 of Set 9 | shelburne
# Processing Record 2 of Set 9 | okato
# Processing Record 3 of Set 9 | governador valadares
# Processing Record 4 of Set 9 | kapoeta
# Processing Record 5 of Set 9 | lujan
# Processing Record 6 of Set 9 | frumusani
# Processing Record 7 of Set 9 | norman wells
# Processing Record 8 of Set 9 | haveri
# Processing Record 9 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 10 of Set 9 | faya
# Processing Record 11 of Set 9 | vostok
# Processing Record 12 of Set 9 | katherine
# Processing Record 13 of Set 9 | ancud
# Processing Record 14 of Set 9 | harper
# Processing Record 15 of Set 9 | sur
# Processing Record 16 of Set 9 | ocampo
# Processing Record 17 of Set 9 | darab
# Processing Record 18 of Set 9 | katangli
# Processing Record 19 of Set 9 | banjarmasin
# Processing Record 20 of Set 9 | malkara
# Processing Record 21 of Set 9 | point pedro
# Processing Record 22 of Set 9 | rock sound
# Processing Record 23 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 9 | vila velha
# Processing Record 25 of Set 9 | najran
# Processing Record 26 of Set 9 | ilo
# Processing Record 27 of Set 9 | corsicana
# Processing Record 28 of Set 9 | magadan
# Processing Record 29 of Set 9 | bireun
# Processing Record 30 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 31 of Set 9 | kudahuvadhoo
# Processing Record 32 of Set 9 | iberia
# Processing Record 33 of Set 9 | zaigrayevo
# Processing Record 34 of Set 9 | vista hermosa
# Processing Record 35 of Set 9 | lima
# Processing Record 36 of Set 9 | soyo
# Processing Record 37 of Set 9 | pangnirtung
# Processing Record 38 of Set 9 | bandarbeyla
# Processing Record 39 of Set 9 | upata
# Processing Record 40 of Set 9 | olafsvik
# Processing Record 41 of Set 9 | haines junction
# Processing Record 42 of Set 9 | kikwit
# Processing Record 43 of Set 9 | oksfjord
# Processing Record 44 of Set 9 | port lincoln
# Processing Record 45 of Set 9 | tiksi
# Processing Record 46 of Set 9 | mogochin
# City not found. Skipping...
# Processing Record 47 of Set 9 | wad madani
# Processing Record 48 of Set 9 | anzio
# Processing Record 49 of Set 9 | lukovetskiy
# Processing Record 50 of Set 9 | novocherkassk
# Processing Record 1 of Set 10 | borba
# Processing Record 2 of Set 10 | almas
# Processing Record 3 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 10 | playa vicente
# Processing Record 5 of Set 10 | monrovia
# Processing Record 6 of Set 10 | okoneshnikovo
# Processing Record 7 of Set 10 | slave lake
# Processing Record 8 of Set 10 | aranda de duero
# Processing Record 9 of Set 10 | san borja
# Processing Record 10 of Set 10 | virden
# Processing Record 11 of Set 10 | poum
# Processing Record 12 of Set 10 | fortuna
# Processing Record 13 of Set 10 | jinchang
# Processing Record 14 of Set 10 | nome
# Processing Record 15 of Set 10 | hamburg
# Processing Record 16 of Set 10 | of
# City not found. Skipping...
# Processing Record 17 of Set 10 | sangar
# Processing Record 18 of Set 10 | aguas vermelhas
# Processing Record 19 of Set 10 | dandong
# Processing Record 20 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 10 | vallenar
# Processing Record 22 of Set 10 | itarema
# Processing Record 23 of Set 10 | bilsi
# Processing Record 24 of Set 10 | pribinic
# Processing Record 25 of Set 10 | odweyne
# Processing Record 26 of Set 10 | mumford
# Processing Record 27 of Set 10 | taoudenni
# Processing Record 28 of Set 10 | hofn
# Processing Record 29 of Set 10 | sinnamary
# Processing Record 30 of Set 10 | portland
# Processing Record 31 of Set 10 | tabat
# Processing Record 32 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 33 of Set 10 | praia da vitoria
# Processing Record 34 of Set 10 | asfi
# Processing Record 35 of Set 10 | alingsas
# Processing Record 36 of Set 10 | dingle
# Processing Record 37 of Set 10 | georgetown
# Processing Record 38 of Set 10 | mishkino
# Processing Record 39 of Set 10 | canberra
# Processing Record 40 of Set 10 | pocone
# Processing Record 41 of Set 10 | neiafu
# Processing Record 42 of Set 10 | misratah
# Processing Record 43 of Set 10 | vao
# Processing Record 44 of Set 10 | heiligenhafen
# Processing Record 45 of Set 10 | linxia
# Processing Record 46 of Set 10 | belmonte
# Processing Record 47 of Set 10 | piryion
# City not found. Skipping...
# Processing Record 48 of Set 10 | vanimo
# Processing Record 49 of Set 10 | bapatla
# Processing Record 50 of Set 10 | tiarei
# Processing Record 1 of Set 11 | nam som
# Processing Record 2 of Set 11 | athabasca
# Processing Record 3 of Set 11 | san juan
# Processing Record 4 of Set 11 | quatre cocos
# Processing Record 5 of Set 11 | nikolayevsk-na-amure
# Processing Record 6 of Set 11 | kamsack
# Processing Record 7 of Set 11 | pompeu
# Processing Record 8 of Set 11 | batavia
# Processing Record 9 of Set 11 | pacific grove
# Processing Record 10 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 11 of Set 11 | waingapu
# Processing Record 12 of Set 11 | caracollo
# Processing Record 13 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 11 | miguel hidalgo
# Processing Record 15 of Set 11 | senador jose porfirio
# Processing Record 16 of Set 11 | birao
# Processing Record 17 of Set 11 | isaka
# Processing Record 18 of Set 11 | whitehorse
# Processing Record 19 of Set 11 | cayenne
# Processing Record 20 of Set 11 | parabel
# Processing Record 21 of Set 11 | calella
# Processing Record 22 of Set 11 | planadas
# Processing Record 23 of Set 11 | margate
# Processing Record 24 of Set 11 | salta
# Processing Record 25 of Set 11 | araripe
# Processing Record 26 of Set 11 | naryan-mar
# Processing Record 27 of Set 11 | acapulco
# Processing Record 28 of Set 11 | minab
# Processing Record 29 of Set 11 | mamakan
# Processing Record 30 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 31 of Set 11 | chapais
# Processing Record 32 of Set 11 | lithgow
# Processing Record 33 of Set 11 | sudova vyshnya
# Processing Record 34 of Set 11 | sri aman
# Processing Record 35 of Set 11 | lempaala
# Processing Record 36 of Set 11 | dakar
# Processing Record 37 of Set 11 | port augusta
# Processing Record 38 of Set 11 | port hawkesbury
# Processing Record 39 of Set 11 | chilca
# Processing Record 40 of Set 11 | abu zabad
# Processing Record 41 of Set 11 | rawson
# Processing Record 42 of Set 11 | zenzeli
# Processing Record 43 of Set 11 | basco
# Processing Record 44 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 45 of Set 11 | kirkwood
# Processing Record 46 of Set 11 | cocorit
# Processing Record 47 of Set 11 | stokmarknes
# Processing Record 48 of Set 11 | matay
# Processing Record 49 of Set 11 | umaria
# Processing Record 50 of Set 11 | suao
# City not found. Skipping...
# Processing Record 1 of Set 12 | burica
# City not found. Skipping...
# Processing Record 2 of Set 12 | eyl
# Processing Record 3 of Set 12 | shafter
# Processing Record 4 of Set 12 | buala
# Processing Record 5 of Set 12 | menomonie
# Processing Record 6 of Set 12 | kamina
# Processing Record 7 of Set 12 | bonfim
# Processing Record 8 of Set 12 | puerto escondido
# Processing Record 9 of Set 12 | maridi
# Processing Record 10 of Set 12 | ningxiang
# Processing Record 11 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 12 of Set 12 | svetlogorsk
# Processing Record 13 of Set 12 | whitianga
# Processing Record 14 of Set 12 | rocha
# Processing Record 15 of Set 12 | morgan city
# Processing Record 16 of Set 12 | yuzhno-kurilsk
# Processing Record 17 of Set 12 | gushikawa
# Processing Record 18 of Set 12 | tungor
# Processing Record 19 of Set 12 | atambua
# Processing Record 20 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 12 | okakarara
# Processing Record 22 of Set 12 | hamilton
# Processing Record 23 of Set 12 | mogadishu
# Processing Record 24 of Set 12 | petrozavodsk
# Processing Record 25 of Set 12 | batagay-alyta
# Processing Record 26 of Set 12 | russell
# Processing Record 27 of Set 12 | puerto del rosario
# Processing Record 28 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 12 | mayumba
# Processing Record 31 of Set 12 | bulgan
# Processing Record 32 of Set 12 | berdavan
# Processing Record 33 of Set 12 | morristown
# Processing Record 34 of Set 12 | polazna
# Processing Record 35 of Set 12 | gallup
# Processing Record 36 of Set 12 | ryotsu
# Processing Record 37 of Set 12 | skovorodino
# Processing Record 38 of Set 12 | zhangjiakou
# Processing Record 39 of Set 12 | jiblah
# Processing Record 40 of Set 12 | buritis
# Processing Record 41 of Set 12 | teknaf
# Processing Record 42 of Set 12 | kandrian
# Processing Record 43 of Set 12 | izacic
# Processing Record 44 of Set 12 | teya
# Processing Record 45 of Set 12 | uyuni
# Processing Record 46 of Set 12 | constitucion
# Processing Record 47 of Set 12 | chicomuselo
# Processing Record 48 of Set 12 | varhaug
# Processing Record 49 of Set 12 | garm
# City not found. Skipping...
# Processing Record 50 of Set 12 | ugoofaaru
# Processing Record 1 of Set 13 | arona
# Processing Record 2 of Set 13 | ballachulish
# Processing Record 3 of Set 13 | hami
# Processing Record 4 of Set 13 | arman
# Processing Record 5 of Set 13 | nurota
# Processing Record 6 of Set 13 | el tigre
# Processing Record 7 of Set 13 | oranjestad
# Processing Record 8 of Set 13 | ginda
# Processing Record 9 of Set 13 | machico
# Processing Record 10 of Set 13 | kaeng khlo
# City not found. Skipping...
# Processing Record 11 of Set 13 | pangoa
# Processing Record 12 of Set 13 | lagoa
# Processing Record 13 of Set 13 | qui nhon
# Processing Record 14 of Set 13 | bubaque
# Processing Record 15 of Set 13 | rio branco
# Processing Record 16 of Set 13 | tongling
# Processing Record 17 of Set 13 | rio gallegos
# Processing Record 18 of Set 13 | tessalit
# Processing Record 19 of Set 13 | villa guerrero
# Processing Record 20 of Set 13 | tateyama
# Processing Record 21 of Set 13 | kabalo
# Processing Record 22 of Set 13 | matola
# Processing Record 23 of Set 13 | tual
# Processing Record 24 of Set 13 | anshun
# Processing Record 25 of Set 13 | requena
# Processing Record 26 of Set 13 | phan thiet
# Processing Record 27 of Set 13 | olinda
# Processing Record 28 of Set 13 | cumberland
# Processing Record 29 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 30 of Set 13 | knysna
# Processing Record 31 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 13 | tambo
# Processing Record 33 of Set 13 | lasa
# Processing Record 34 of Set 13 | itaituba
# Processing Record 35 of Set 13 | banjar
# Processing Record 36 of Set 13 | hanzhong
# Processing Record 37 of Set 13 | santa maria
# Processing Record 38 of Set 13 | roald
# Processing Record 39 of Set 13 | tamandare
# Processing Record 40 of Set 13 | awbari
# Processing Record 41 of Set 13 | maragogi
# Processing Record 42 of Set 13 | baoding
# Processing Record 43 of Set 13 | college
# Processing Record 44 of Set 13 | mangochi
# Processing Record 45 of Set 13 | tolaga bay
# Processing Record 46 of Set 13 | kitimat
# Processing Record 47 of Set 13 | ploemeur
# Processing Record 48 of Set 13 | genhe
# Processing Record 49 of Set 13 | itoman
# Processing Record 50 of Set 13 | sioux lookout
# Processing Record 1 of Set 14 | goma
# Processing Record 2 of Set 14 | ryde
# Processing Record 3 of Set 14 | pochutla
# Processing Record 4 of Set 14 | san andres
# Processing Record 5 of Set 14 | kommunisticheskiy
# Processing Record 6 of Set 14 | payakumbuh
# Processing Record 7 of Set 14 | corinto
# Processing Record 8 of Set 14 | jasper
# Processing Record 9 of Set 14 | alexandria
# Processing Record 10 of Set 14 | kirakira
# Processing Record 11 of Set 14 | yanam
# Processing Record 12 of Set 14 | kristiansund
# Processing Record 13 of Set 14 | rawlins
# Processing Record 14 of Set 14 | moron
# Processing Record 15 of Set 14 | srikakulam
# Processing Record 16 of Set 14 | champua
# Processing Record 17 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 14 | longonjo
# Processing Record 19 of Set 14 | leh
# Processing Record 20 of Set 14 | carbonia
# Processing Record 21 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 22 of Set 14 | acarau
# Processing Record 23 of Set 14 | northam
# Processing Record 24 of Set 14 | half moon bay
# Processing Record 25 of Set 14 | matamoros
# Processing Record 26 of Set 14 | zaysan
# Processing Record 27 of Set 14 | bako
# Processing Record 28 of Set 14 | montmagny
# Processing Record 29 of Set 14 | sarandi
# Processing Record 30 of Set 14 | selma
# Processing Record 31 of Set 14 | chernyshevskiy
# Processing Record 32 of Set 14 | broken hill
# Processing Record 33 of Set 14 | merauke
# Processing Record 34 of Set 14 | pryluky
# Processing Record 35 of Set 14 | taitung
# Processing Record 36 of Set 14 | port macquarie
# Processing Record 37 of Set 14 | libertador general san martin
# Processing Record 38 of Set 14 | yegorlykskaya
# Processing Record 39 of Set 14 | redlands
# Processing Record 40 of Set 14 | pangai
# Processing Record 41 of Set 14 | huicungo
# Processing Record 42 of Set 14 | lokosovo
# Processing Record 43 of Set 14 | havelock
# Processing Record 44 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 45 of Set 14 | paka
# Processing Record 46 of Set 14 | belawan
# Processing Record 47 of Set 14 | mundo nuevo
# Processing Record 48 of Set 14 | gurjaani
# Processing Record 49 of Set 14 | gilgit
# Processing Record 50 of Set 14 | kolaras
# Processing Record 1 of Set 15 | villa carlos paz
# Processing Record 2 of Set 15 | terme
# Processing Record 3 of Set 15 | akividu
# Processing Record 4 of Set 15 | ostrovnoy
# Processing Record 5 of Set 15 | guaruja
# Processing Record 6 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 15 | lappeenranta
# Processing Record 8 of Set 15 | richards bay
# Processing Record 9 of Set 15 | fairbanks
# Processing Record 10 of Set 15 | bhabua
# Processing Record 11 of Set 15 | qiongshan
# Processing Record 12 of Set 15 | gat
# Processing Record 13 of Set 15 | saint anthony
# Processing Record 14 of Set 15 | alvaraes
# Processing Record 15 of Set 15 | sao filipe
# Processing Record 16 of Set 15 | tete
# Processing Record 17 of Set 15 | porto san giorgio
# Processing Record 18 of Set 15 | bafoulabe
# Processing Record 19 of Set 15 | marfino
# Processing Record 20 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 21 of Set 15 | kathmandu
# Processing Record 22 of Set 15 | panguna
# Processing Record 23 of Set 15 | nongstoin
# Processing Record 24 of Set 15 | les cayes
# Processing Record 25 of Set 15 | abalak
# Processing Record 26 of Set 15 | tandur
# Processing Record 27 of Set 15 | osinki
# Processing Record 28 of Set 15 | nuuk
# Processing Record 29 of Set 15 | paita
# Processing Record 30 of Set 15 | peniche
# Processing Record 31 of Set 15 | kyaikkami
# Processing Record 32 of Set 15 | buluang
# Processing Record 33 of Set 15 | onega
# Processing Record 34 of Set 15 | lethem
# Processing Record 35 of Set 15 | srednekolymsk
# Processing Record 36 of Set 15 | tshane
# Processing Record 37 of Set 15 | comodoro rivadavia
# Processing Record 38 of Set 15 | goderich
# Processing Record 39 of Set 15 | trinidad
# Processing Record 40 of Set 15 | lugovoy
# Processing Record 41 of Set 15 | den helder
# Processing Record 42 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 43 of Set 15 | hinton
# Processing Record 44 of Set 15 | niquelandia
# Processing Record 45 of Set 15 | nara
# Processing Record 46 of Set 15 | buraydah
# Processing Record 47 of Set 15 | isangel
# Processing Record 48 of Set 15 | namibe
# Processing Record 49 of Set 15 | mitchell
# Processing Record 50 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 16 | cap malheureux
# Processing Record 2 of Set 16 | orgun
# City not found. Skipping...
# Processing Record 3 of Set 16 | artyom
# Processing Record 4 of Set 16 | puerto madero
# Processing Record 5 of Set 16 | solano
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Muros  42.7762   -9.0603     41.00        82          96        5.68
# 1      Hasaki  35.7333  140.8333     66.00        29          75        6.91
# 2        Hilo  19.7297 -155.0900     73.40        73          90       12.66
# 3      Hirara  24.8000  125.2833     71.60        53          40       21.85
# 4  Olenegorsk  68.1500   33.3000     36.10        89          81        8.55
# 5      Yulara -25.2406  130.9889     75.20        20           0       14.97
# 6  Banda Aceh   5.5577   95.3222     85.75        67          43        8.14
# 7     Samarai -10.6167  150.6667     83.98        74          72       14.85
# 8     Ushuaia -54.8000  -68.3000     51.80        54          40       10.36
# 9       Bluff -46.6000  168.3333     55.00        71          87        1.99
#
#   Country Current Description
# 0      ES     overcast clouds
# 1      JP       broken clouds
# 2      US     overcast clouds
# 3      JP    scattered clouds
# 4      RU       broken clouds
# 5      AU           clear sky
# 6      ID    scattered clouds
# 7      PG       broken clouds
# 8      AR    scattered clouds
# 9      NZ     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp",  "Humidity", "Cloudiness", "Current Description",]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Muros      ES  42.7762   -9.0603     41.00        82          96
# 1      Hasaki      JP  35.7333  140.8333     66.00        29          75
# 2        Hilo      US  19.7297 -155.0900     73.40        73          90
# 3      Hirara      JP  24.8000  125.2833     71.60        53          40
# 4  Olenegorsk      RU  68.1500   33.3000     36.10        89          81
# 5      Yulara      AU -25.2406  130.9889     75.20        20           0
# 6  Banda Aceh      ID   5.5577   95.3222     85.75        67          43
# 7     Samarai      PG -10.6167  150.6667     83.98        74          72
# 8     Ushuaia      AR -54.8000  -68.3000     51.80        54          40
# 9       Bluff      NZ -46.6000  168.3333     55.00        71          87
#
#   Current Description
# 0     overcast clouds
# 1       broken clouds
# 2     overcast clouds
# 3    scattered clouds
# 4       broken clouds
# 5           clear sky
# 6    scattered clouds
# 7       broken clouds
# 8    scattered clouds
# 9     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
